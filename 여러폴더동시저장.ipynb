# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import SimpleITK as sitk

# %%
c_path = 'C:/Users/sungjoo/Desktop/c-spine/'
# org_path = 'C:/Users/sungjoo/Desktop/original/'
save_path = 'C:/Users/sungjoo/Desktop/c-spine-dcm/'
print(len(os.listdir(org_path)))
print(os.listdir(org_path)[0])
c_list = os.listdir(c_path)
print(len(c_list))
new_list = os.listdir(save_path)
print(len(new_list))
# Out:
# 7650
# tmp_HIRA20_CF_000001.dcm
# 131
# 130

# %%
for i in range(len(c_list)):
#     com = cv2.imread(os.path.join(comb_path,os.listdir(comb_path)[i]),0)
    for j in range(len(new_list)):
        if c_list[i].split('.')[-2]!=new_list[j].split('.')[-2]:
            print(c_list[i])
# Out:
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# tmp_HIRA20_CF_000183.png
# ...
